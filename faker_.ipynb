# %%
from faker import Faker
import pandas as pd
fake = Faker()
data = [fake.profile() for i in range(10000)]
data = pd.DataFrame(data)

# %%
data
# Out:
#                                   job                    company          ssn  \
# 0         Industrial/product designer              Owens-Mcclure  237-90-4775
# 1                 Engineer, petroleum                   Cook Inc  330-54-3540
# 2                     Hospital doctor                Lucas-Perry  508-95-9898
# 3                          Bookseller           Williams-Jackson  611-24-3757
# 4                   Recycling officer                Mata-Gibson  606-74-6381
# ...                               ...                        ...          ...
# 9995                Ceramics designer               Robinson LLC  304-62-4309
# 9996  Producer, television/film/video             Alexander-Rios  548-03-2471
# 9997                 Network engineer  Mckee, Mason and Johnston  849-75-1227
# 9998             Field trials officer   Martinez, Lynn and Jones  460-41-8441
# 9999                 Health physicist                 Reed-Allen  426-32-0825
#
# ...
